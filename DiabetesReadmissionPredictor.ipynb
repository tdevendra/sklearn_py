# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %%
df = pd.read_csv(r"G:\Machine Learning\mlcsv\dataset_diabetes\diabetic_data.csv")

# %%
df.fillna(method='ffill', inplace=True)

# %%
df.replace("None", np.nan, inplace=True)

# %%
pd.crosstab(df.admission_type_id,df.readmitted).plot(kind='bar')
# Here we can see that readmission for > 30 or < 30 days is highest in case of admission type 1 i.e. emergency, 
# followed by 2 and 3 i.e. urgent and elective

# %%
pd.crosstab(df.discharge_disposition_id, df.readmitted).plot(kind='bar')
# Again, For discharge type, 1 i.e. discharged to home, readmission is high,
# followed by 3 and 6 i.e. transfered to SNF or home with health service

# %%
sns.boxplot(x="admission_type_id", y="age", data=df)

# %%
df.columns
# Out:
# Index(['encounter_id', 'patient_nbr', 'race', 'gender', 'age', 'weight',
#        'admission_type_id', 'discharge_disposition_id', 'admission_source_id',
#        'time_in_hospital', 'payer_code', 'medical_specialty',
#        'num_lab_procedures', 'num_procedures', 'num_medications',
#        'number_outpatient', 'number_emergency', 'number_inpatient', 'diag_1',
#        'diag_2', 'diag_3', 'number_diagnoses', 'max_glu_serum', 'A1Cresult',
#        'metformin', 'repaglinide', 'nateglinide', 'chlorpropamide',
#        'glimepiride', 'acetohexamide', 'glipizide', 'glyburide', 'tolbutamide',
#        'pioglitazone', 'rosiglitazone', 'acarbose', 'miglitol', 'troglitazone',
#        'tolazamide', 'examide', 'citoglipton', 'insulin',
#        'glyburide-metformin', 'glipizide-metformin',
#        'glimepiride-pioglitazone', 'metformin-rosiglitazone',
#        'metformin-pioglitazone', 'change', 'diabetesMed', 'readmitted'],
#       dtype='object')

# %%
df.drop(["weight", "payer_code"], axis=1, inplace=True)

# %%
df.drop(['encounter_id'], axis=1, inplace=True)

# %%
df.head(5)
# Out:
#    patient_nbr             race  gender      age  admission_type_id  \
# 0      8222157        Caucasian  Female   [0-10)                  6
# 1     55629189        Caucasian  Female  [10-20)                  1
# 2     86047875  AfricanAmerican  Female  [20-30)                  1
# 3     82442376        Caucasian    Male  [30-40)                  1
# 4     42519267        Caucasian    Male  [40-50)                  1
#
#    discharge_disposition_id  admission_source_id  time_in_hospital  \
# 0                        25                    1                 1
# 1                         1                    7                 3
# 2                         1                    7                 2
# 3                         1                    7                 2
# 4                         1                    7                 1
#
#           medical_specialty  num_lab_procedures  ...  citoglipton  insulin  \
# 0  Pediatrics-Endocrinology                  41  ...           No       No
# 1                         ?                  59  ...           No       Up
# 2                         ?                  11  ...           No       No
# 3                         ?                  44  ...           No       Up
# 4                         ?                  51  ...           No   Steady
#
#    glyburide-metformin  glipizide-metformin  glimepiride-pioglitazone  \
# 0                   No                   No                        No
# 1                   No                   No                        No
# 2                   No                   No                        No
# 3                   No                   No                        No
# 4                   No                   No                        No
#
#   metformin-rosiglitazone metformin-pioglitazone change  diabetesMed  \
# 0                      No                     No     No           No
# 1                      No                     No     Ch          Yes
# 2                      No                     No     No          Yes
# 3                      No                     No     Ch          Yes
# 4                      No                     No     Ch          Yes
#
#   readmitted
# 0         NO
# 1        >30
# 2         NO
# 3         NO
# 4         NO
#
# [5 rows x 47 columns]

# %%
df.medical_specialty.replace("?", np.nan, inplace=True)

# %%
df.medical_specialty.isna().sum()
# Out:
# 49949

# %%
sns.heatmap(df.isna(), yticklabels=False, cmap='viridis')

# %%
df.isna().sum()
# Out:
# patient_nbr                     0
# race                            0
# gender                          0
# age                             0
# admission_type_id               0
# discharge_disposition_id        0
# admission_source_id             0
# time_in_hospital                0
# medical_specialty           49949
# num_lab_procedures              0
# num_procedures                  0
# num_medications                 0
# number_outpatient               0
# number_emergency                0
# number_inpatient                0
# diag_1                          0
# diag_2                          0
# diag_3                          0
# number_diagnoses                0
# max_glu_serum               96420
# A1Cresult                   84748
# metformin                       0
# repaglinide                     0
# nateglinide                     0
# chlorpropamide                  0
# glimepiride                     0
# acetohexamide                   0
# glipizide                       0
# glyburide                       0
# tolbutamide                     0
# pioglitazone                    0
# rosiglitazone                   0
# acarbose                        0
# miglitol                        0
# troglitazone                    0
# tolazamide                      0
# examide                         0
# citoglipton                     0
# insulin                         0
# glyburide-metformin             0
# glipizide-metformin             0
# glimepiride-pioglitazone        0
# metformin-rosiglitazone         0
# metformin-pioglitazone          0
# change                          0
# diabetesMed                     0
# readmitted                      0
# dtype: int64

# %%
df.dropna(inplace=True)

# %%
sns.heatmap(df.isna(), yticklabels=False, cmap='viridis')
# Ok, now its clean

# %%
df.columns
# Out:
# Index(['patient_nbr', 'race', 'gender', 'age', 'admission_type_id',
#        'discharge_disposition_id', 'admission_source_id', 'time_in_hospital',
#        'medical_specialty', 'num_lab_procedures', 'num_procedures',
#        'num_medications', 'number_outpatient', 'number_emergency',
#        'number_inpatient', 'diag_1', 'diag_2', 'diag_3', 'number_diagnoses',
#        'max_glu_serum', 'A1Cresult', 'metformin', 'repaglinide', 'nateglinide',
#        'chlorpropamide', 'glimepiride', 'acetohexamide', 'glipizide',
#        'glyburide', 'tolbutamide', 'pioglitazone', 'rosiglitazone', 'acarbose',
#        'miglitol', 'troglitazone', 'tolazamide', 'examide', 'citoglipton',
#        'insulin', 'glyburide-metformin', 'glipizide-metformin',
#        'glimepiride-pioglitazone', 'metformin-rosiglitazone',
#        'metformin-pioglitazone', 'change', 'diabetesMed', 'readmitted'],
#       dtype='object')

# %%
df.miglitol.unique()
# Out:
# array(['No'], dtype=object)

# %%
df.troglitazone.unique()
# Out:
# array(['No'], dtype=object)

# %%
df.tolazamide.unique()
# Out:
# array(['No'], dtype=object)

# %%
df.examide.unique()
# Out:
# array(['No'], dtype=object)

# %%
df.acarbose.unique()
# Out:
# array(['No', 'Steady'], dtype=object)

# %%
df.acarbose[df.acarbose == "Steady"].count()
# Out:
# 1

# %%
df.drop(["miglitol", "troglitazone", "tolazamide", "examide", "acarbose"], axis=1, inplace=True)

# %%
df.head(10)
# Out:
#       patient_nbr             race  gender      age  admission_type_id  \
# 1755     82255599        Caucasian  Female  [50-60)                  6
# 1983     66062943        Caucasian    Male  [50-60)                  6
# 2079     77283603  AfricanAmerican  Female  [70-80)                  6
# 2308    103731444         Hispanic  Female  [70-80)                  6
# 3276     64565010        Caucasian    Male  [70-80)                  6
# 4856     69532245        Caucasian  Female  [60-70)                  6
# 5015     50977674  AfricanAmerican  Female  [50-60)                  6
# 5312     60115239        Caucasian  Female  [70-80)                  6
# 5387    109789992        Caucasian    Male  [80-90)                  6
# 5770     58968585        Caucasian  Female  [70-80)                  6
#
#       discharge_disposition_id  admission_source_id  time_in_hospital  \
# 1755                         1                    7                 2
# 1983                        10                    1                 4
# 2079                         1                    7                 3
# 2308                         6                    7                 6
# 3276                         3                    7                 4
# 4856                         1                    7                 6
# 5015                         1                    7                 5
# 5312                         1                    7                 7
# 5387                         1                    7                 4
# 5770                         1                    7                 4
#
#      medical_specialty  num_lab_procedures  ...  citoglipton  insulin  \
# 1755  InternalMedicine                  43  ...           No       No
# 1983   Surgery-General                  41  ...           No       No
# 2079  InternalMedicine                  43  ...           No       No
# 2308  InternalMedicine                  69  ...           No       No
# 3276  InternalMedicine                  64  ...           No       No
# 4856  InternalMedicine                  77  ...           No   Steady
# 5015  InternalMedicine                  95  ...           No   Steady
# 5312  InternalMedicine                  67  ...           No       No
# 5387  InternalMedicine                  74  ...           No       No
# 5770  InternalMedicine                  65  ...           No   Steady
#
#       glyburide-metformin  glipizide-metformin  glimepiride-pioglitazone  \
# 1755                   No                   No                        No
# 1983                   No                   No                        No
# 2079                   No                   No                        No
# 2308                   No                   No                        No
# 3276                   No                   No                        No
# 4856                   No                   No                        No
# 5015                   No                   No                        No
# 5312                   No                   No                        No
# 5387                   No                   No                        No
# 5770                   No                   No                        No
#
#      metformin-rosiglitazone metformin-pioglitazone change  diabetesMed  \
# 1755                      No                     No     No           No
# 1983                      No                     No     No          Yes
# 2079                      No                     No     No           No
# 2308                      No                     No     No           No
# 3276                      No                     No     No          Yes
# 4856                      No                     No     No          Yes
# 5015                      No                     No     No          Yes
# 5312                      No                     No     No           No
# 5387                      No                     No     No           No
# 5770                      No                     No     No          Yes
#
#      readmitted
# 1755        >30
# 1983        >30
# 2079        >30
# 2308        >30
# 3276        >30
# 4856        >30
# 5015        >30
# 5312         NO
# 5387        >30
# 5770        >30
#
# [10 rows x 42 columns]

# %%
df.columns
# Out:
# Index(['patient_nbr', 'race', 'gender', 'age', 'admission_type_id',
#        'discharge_disposition_id', 'admission_source_id', 'time_in_hospital',
#        'medical_specialty', 'num_lab_procedures', 'num_procedures',
#        'num_medications', 'number_outpatient', 'number_emergency',
#        'number_inpatient', 'diag_1', 'diag_2', 'diag_3', 'number_diagnoses',
#        'max_glu_serum', 'A1Cresult', 'metformin', 'repaglinide', 'nateglinide',
#        'chlorpropamide', 'glimepiride', 'acetohexamide', 'glipizide',
#        'glyburide', 'tolbutamide', 'pioglitazone', 'rosiglitazone',
#        'citoglipton', 'insulin', 'glyburide-metformin', 'glipizide-metformin',
#        'glimepiride-pioglitazone', 'metformin-rosiglitazone',
#        'metformin-pioglitazone', 'change', 'diabetesMed', 'readmitted'],
#       dtype='object')

# %%
df.tolbutamide.unique()
# Out:
# array(['No'], dtype=object)

# %%
df.pioglitazone.unique()
# Out:
# array(['No', 'Steady'], dtype=object)

# %%
df.pioglitazone[df.pioglitazone == "No"].count()
# Out:
# 137

# %%
df.pioglitazone[df.pioglitazone == "Steady"].count()
# Out:
# 7

# %%
df.rosiglitazone.unique()
# Out:
# array(['No', 'Steady'], dtype=object)

# %%
df.rosiglitazone[df.rosiglitazone == "Steady"].count()
# Out:
# 5

# %%
df.repaglinide.unique()
# Out:
# array(['No', 'Steady'], dtype=object)

# %%
df.nateglinide.unique()
# Out:
# array(['No', 'Steady'], dtype=object)

# %%
df.chlorpropamide.unique()
# Out:
# array(['No'], dtype=object)

# %%
df.head(5)
# Out:
#       patient_nbr             race  gender      age  admission_type_id  \
# 1755     82255599        Caucasian  Female  [50-60)                  6
# 1983     66062943        Caucasian    Male  [50-60)                  6
# 2079     77283603  AfricanAmerican  Female  [70-80)                  6
# 2308    103731444         Hispanic  Female  [70-80)                  6
# 3276     64565010        Caucasian    Male  [70-80)                  6
#
#       discharge_disposition_id  admission_source_id  time_in_hospital  \
# 1755                         1                    7                 2
# 1983                        10                    1                 4
# 2079                         1                    7                 3
# 2308                         6                    7                 6
# 3276                         3                    7                 4
#
#      medical_specialty  num_lab_procedures  ...  citoglipton  insulin  \
# 1755  InternalMedicine                  43  ...           No       No
# 1983   Surgery-General                  41  ...           No       No
# 2079  InternalMedicine                  43  ...           No       No
# 2308  InternalMedicine                  69  ...           No       No
# 3276  InternalMedicine                  64  ...           No       No
#
#       glyburide-metformin  glipizide-metformin  glimepiride-pioglitazone  \
# 1755                   No                   No                        No
# 1983                   No                   No                        No
# 2079                   No                   No                        No
# 2308                   No                   No                        No
# 3276                   No                   No                        No
#
#      metformin-rosiglitazone metformin-pioglitazone change  diabetesMed  \
# 1755                      No                     No     No           No
# 1983                      No                     No     No          Yes
# 2079                      No                     No     No           No
# 2308                      No                     No     No           No
# 3276                      No                     No     No          Yes
#
#      readmitted
# 1755        >30
# 1983        >30
# 2079        >30
# 2308        >30
# 3276        >30
#
# [5 rows x 42 columns]

# %%
df.join(pd.get_dummies(df.race, drop_first=True))
# Out:
#         patient_nbr             race  gender      age  admission_type_id  \
# 1755       82255599        Caucasian  Female  [50-60)                  6
# 1983       66062943        Caucasian    Male  [50-60)                  6
# 2079       77283603  AfricanAmerican  Female  [70-80)                  6
# 2308      103731444         Hispanic  Female  [70-80)                  6
# 3276       64565010        Caucasian    Male  [70-80)                  6
# 4856       69532245        Caucasian  Female  [60-70)                  6
# 5015       50977674  AfricanAmerican  Female  [50-60)                  6
# 5312       60115239        Caucasian  Female  [70-80)                  6
# 5387      109789992        Caucasian    Male  [80-90)                  6
# 5770       58968585        Caucasian  Female  [70-80)                  6
# 6128       62530920        Caucasian    Male  [70-80)                  6
# 6451       83398734        Caucasian    Male  [70-80)                  6
# 6952       89347266        Caucasian  Female  [80-90)                  6
# 7697       56097081            Other    Male  [60-70)                  6
# 8269       11437938         Hispanic  Female  [20-30)                  6
# 9118       48102489  AfricanAmerican    Male  [40-50)                  6
# 9470        3972258  AfricanAmerican  Female  [50-60)                  6
# 9688       68191632                ?  Female  [60-70)                  6
# 10039      88043805        Caucasian    Male  [70-80)                  6
# 11978      96818643        Caucasian    Male  [40-50)                  6
# 12274     103989645        Caucasian    Male  [50-60)                  6
# 12837     106892919        Caucasian  Female  [50-60)                  6
# 13364      18553995        Caucasian    Male  [60-70)                  6
# 13548        822798        Caucasian    Male  [80-90)                  6
# 13633      55848618        Caucasian  Female  [70-80)                  6
# 14643     114688998        Caucasian    Male  [70-80)                  6
# 15358      45264798            Other  Female  [30-40)                  6
# 15537      77804226        Caucasian  Female  [50-60)                  6
# 15582      74272752        Caucasian    Male  [40-50)                  6
# 16430      93417543        Caucasian  Female  [80-90)                  6
# ...             ...              ...     ...      ...                ...
# 67715      90918144        Caucasian  Female  [70-80)                  6
# 68025      70243965        Caucasian  Female  [80-90)                  6
# 68268     104363523        Caucasian    Male  [40-50)                  6
# 68574     103087764                ?  Female  [50-60)                  6
# 68769       3306996        Caucasian    Male  [50-60)                  6
# 69009       2688507         Hispanic    Male  [40-50)                  6
# 69620     112498695        Caucasian    Male  [50-60)                  6
# 69626      49308876        Caucasian  Female  [80-90)                  6
# 70356      59783895         Hispanic  Female  [60-70)                  6
# 74830      98405307        Caucasian  Female  [50-60)                  6
# 75403      70595991        Caucasian  Female  [70-80)                  6
# 75660       1275921         Hispanic    Male  [30-40)                  6
# 76452     105869664  AfricanAmerican  Female  [70-80)                  6
# 79191      81529029        Caucasian  Female  [50-60)                  6
# 79344      64565010        Caucasian    Male  [70-80)                  6
# 80410      71833095        Caucasian    Male  [50-60)                  6
# 82473      63780093        Caucasian    Male  [80-90)                  6
# 82659     102838752  AfricanAmerican  Female  [60-70)                  6
# 84339      11246310        Caucasian    Male  [80-90)                  6
# 85249      68737824         Hispanic  Female  [70-80)                  6
# 86640      57932163        Caucasian    Male  [50-60)                  6
# 86941      88995861        Caucasian  Female  [80-90)                  6
# 87730      79526916  AfricanAmerican  Female  [40-50)                  6
# 91880      85069584         Hispanic  Female  [60-70)                  6
# 93893     124870523         Hispanic    Male  [50-60)                  6
# 94139      62022393        Caucasian  Female  [70-80)                  6
# 94518      98236980        Caucasian    Male  [70-80)                  6
# 97083      78042069        Caucasian    Male  [50-60)                  6
# 98207      21390165        Caucasian    Male  [60-70)                  6
# 101088    126428594  AfricanAmerican    Male  [40-50)                  6
#
#         discharge_disposition_id  admission_source_id  time_in_hospital  \
# 1755                           1                    7                 2
# 1983                          10                    1                 4
# 2079                           1                    7                 3
# 2308                           6                    7                 6
# 3276                           3                    7                 4
# 4856                           1                    7                 6
# 5015                           1                    7                 5
# 5312                           1                    7                 7
# 5387                           1                    7                 4
# 5770                           1                    7                 4
# 6128                           1                    7                 9
# 6451                           2                    7                 5
# 6952                           1                    7                 2
# 7697                           3                    7                10
# 8269                           1                    7                 1
# 9118                           1                    7                 4
# 9470                           1                    7                 5
# 9688                           3                    7                 6
# 10039                          1                    7                 6
# 11978                          1                    1                13
# 12274                          2                    7                 2
# 12837                          7                    1                 1
# 13364                          5                    7                 6
# 13548                          5                    7                14
# 13633                          3                    7                 6
# 14643                          1                    7                 2
# 15358                          1                    7                 1
# 15537                          1                    7                14
# 15582                          1                    7                 5
# 16430                         13                    7                 8
# ...                          ...                  ...               ...
# 67715                          6                    7                 6
# 68025                          3                    7                 5
# 68268                          7                    7                 1
# 68574                          1                    7                12
# 68769                          1                    7                 2
# 69009                          1                    7                 2
# 69620                          1                    7                 4
# 69626                          1                    7                 8
# 70356                          3                    7                 4
# 74830                          1                    7                 4
# 75403                          6                    7                 5
# 75660                          1                    7                 4
# 76452                          1                    7                 5
# 79191                          1                    7                 2
# 79344                          6                    1                 8
# 80410                          7                    7                 1
# 82473                          1                    1                 3
# 82659                          3                    7                 6
# 84339                          3                    7                 8
# 85249                          6                    7                 3
# 86640                          1                    7                 2
# 86941                          3                    7                10
# 87730                          3                    7                 7
# 91880                          1                    7                 1
# 93893                          1                    7                 1
# 94139                          3                    7                 5
# 94518                          1                    7                 3
# 97083                          6                    7                 4
# 98207                          1                    7                 3
# 101088                         7                    7                 2
#
#        medical_specialty  num_lab_procedures  ...  metformin-rosiglitazone  \
# 1755    InternalMedicine                  43  ...                       No
# 1983     Surgery-General                  41  ...                       No
# 2079    InternalMedicine                  43  ...                       No
# 2308    InternalMedicine                  69  ...                       No
# 3276    InternalMedicine                  64  ...                       No
# 4856    InternalMedicine                  77  ...                       No
# 5015    InternalMedicine                  95  ...                       No
# 5312    InternalMedicine                  67  ...                       No
# 5387    InternalMedicine                  74  ...                       No
# 5770    InternalMedicine                  65  ...                       No
# 6128    InternalMedicine                  53  ...                       No
# 6451    InternalMedicine                  45  ...                       No
# 6952    InternalMedicine                  68  ...                       No
# 7697    InternalMedicine                  81  ...                       No
# 8269    InternalMedicine                  65  ...                       No
# 9118    InternalMedicine                  78  ...                       No
# 9470    InternalMedicine                  98  ...                       No
# 9688    InternalMedicine                  79  ...                       No
# 10039   InternalMedicine                  62  ...                       No
# 11978    Surgery-General                  75  ...                       No
# 12274   InternalMedicine                  63  ...                       No
# 12837   InternalMedicine                  47  ...                       No
# 13364   InternalMedicine                  67  ...                       No
# 13548   InternalMedicine                  77  ...                       No
# 13633   InternalMedicine                  71  ...                       No
# 14643   InternalMedicine                  61  ...                       No
# 15358   InternalMedicine                  87  ...                       No
# 15537   InternalMedicine                  81  ...                       No
# 15582   InternalMedicine                  56  ...                       No
# 16430   InternalMedicine                  96  ...                       No
# ...                  ...                 ...  ...                      ...
# 67715   InternalMedicine                  67  ...                       No
# 68025   InternalMedicine                  64  ...                       No
# 68268   InternalMedicine                  38  ...                       No
# 68574    Surgery-General                  75  ...                       No
# 68769   InternalMedicine                  66  ...                       No
# 69009   InternalMedicine                  48  ...                       No
# 69620   InternalMedicine                  87  ...                       No
# 69626   InternalMedicine                  62  ...                       No
# 70356   InternalMedicine                  59  ...                       No
# 74830   InternalMedicine                  48  ...                       No
# 75403   InternalMedicine                  57  ...                       No
# 75660   InternalMedicine                  76  ...                       No
# 76452   InternalMedicine                  50  ...                       No
# 79191   InternalMedicine                  71  ...                       No
# 79344   InternalMedicine                  52  ...                       No
# 80410   InternalMedicine                  49  ...                       No
# 82473   InternalMedicine                  62  ...                       No
# 82659   InternalMedicine                  61  ...                       No
# 84339   InternalMedicine                  56  ...                       No
# 85249   InternalMedicine                  63  ...                       No
# 86640   InternalMedicine                  67  ...                       No
# 86941   InternalMedicine                  93  ...                       No
# 87730   InternalMedicine                  76  ...                       No
# 91880   InternalMedicine                  50  ...                       No
# 93893   InternalMedicine                  88  ...                       No
# 94139   InternalMedicine                  97  ...                       No
# 94518   InternalMedicine                  40  ...                       No
# 97083   InternalMedicine                  49  ...                       No
# 98207   InternalMedicine                  69  ...                       No
# 101088  InternalMedicine                  60  ...                       No
#
#         metformin-pioglitazone  change  diabetesMed  readmitted  \
# 1755                        No      No           No         >30
# 1983                        No      No          Yes         >30
# 2079                        No      No           No         >30
# 2308                        No      No           No         >30
# 3276                        No      No          Yes         >30
# 4856                        No      No          Yes         >30
# 5015                        No      No          Yes         >30
# 5312                        No      No           No          NO
# 5387                        No      No           No         >30
# 5770                        No      No          Yes         >30
# 6128                        No      Ch          Yes         >30
# 6451                        No      No          Yes         >30
# 6952                        No      No           No          NO
# 7697                        No      No          Yes          NO
# 8269                        No      Ch          Yes          NO
# 9118                        No      Ch          Yes          NO
# 9470                        No      No          Yes          NO
# 9688                        No      Ch          Yes         <30
# 10039                       No      Ch          Yes         >30
# 11978                       No      Ch          Yes         >30
# 12274                       No      Ch          Yes         >30
# 12837                       No      Ch          Yes         >30
# 13364                       No      Ch          Yes          NO
# 13548                       No      No          Yes         >30
# 13633                       No      No          Yes         <30
# 14643                       No      No           No          NO
# 15358                       No      Ch          Yes         >30
# 15537                       No      Ch          Yes         >30
# 15582                       No      No          Yes          NO
# 16430                       No      No          Yes          NO
# ...                        ...     ...          ...         ...
# 67715                       No      No          Yes          NO
# 68025                       No      No          Yes          NO
# 68268                       No      No           No         >30
# 68574                       No      Ch          Yes          NO
# 68769                       No      No           No          NO
# 69009                       No      Ch          Yes          NO
# 69620                       No      No          Yes         >30
# 69626                       No      No          Yes         >30
# 70356                       No      No          Yes         >30
# 74830                       No      No          Yes         >30
# 75403                       No      No          Yes          NO
# 75660                       No      Ch          Yes          NO
# 76452                       No      No          Yes          NO
# 79191                       No      Ch          Yes         >30
# 79344                       No      No          Yes          NO
# 80410                       No      Ch          Yes          NO
# 82473                       No      No           No         >30
# 82659                       No      No          Yes         >30
# 84339                       No      No           No         >30
# 85249                       No      Ch          Yes          NO
# 86640                       No      No           No          NO
# 86941                       No      Ch          Yes         <30
# 87730                       No      No          Yes         <30
# 91880                       No      No          Yes         <30
# 93893                       No      No           No          NO
# 94139                       No      No           No          NO
# 94518                       No      No           No          NO
# 97083                       No      No          Yes         >30
# 98207                       No      Ch          Yes          NO
# 101088                      No      Ch          Yes          NO
#
#        AfricanAmerican Asian Caucasian  Hispanic Other
# 1755                 0     0         1         0     0
# 1983                 0     0         1         0     0
# 2079                 1     0         0         0     0
# 2308                 0     0         0         1     0
# 3276                 0     0         1         0     0
# 4856                 0     0         1         0     0
# 5015                 1     0         0         0     0
# 5312                 0     0         1         0     0
# 5387                 0     0         1         0     0
# 5770                 0     0         1         0     0
# 6128                 0     0         1         0     0
# 6451                 0     0         1         0     0
# 6952                 0     0         1         0     0
# 7697                 0     0         0         0     1
# 8269                 0     0         0         1     0
# 9118                 1     0         0         0     0
# 9470                 1     0         0         0     0
# 9688                 0     0         0         0     0
# 10039                0     0         1         0     0
# 11978                0     0         1         0     0
# 12274                0     0         1         0     0
# 12837                0     0         1         0     0
# 13364                0     0         1         0     0
# 13548                0     0         1         0     0
# 13633                0     0         1         0     0
# 14643                0     0         1         0     0
# 15358                0     0         0         0     1
# 15537                0     0         1         0     0
# 15582                0     0         1         0     0
# 16430                0     0         1         0     0
# ...                ...   ...       ...       ...   ...
# 67715                0     0         1         0     0
# 68025                0     0         1         0     0
# 68268                0     0         1         0     0
# 68574                0     0         0         0     0
# 68769                0     0         1         0     0
# 69009                0     0         0         1     0
# 69620                0     0         1         0     0
# 69626                0     0         1         0     0
# 70356                0     0         0         1     0
# 74830                0     0         1         0     0
# 75403                0     0         1         0     0
# 75660                0     0         0         1     0
# 76452                1     0         0         0     0
# 79191                0     0         1         0     0
# 79344                0     0         1         0     0
# 80410                0     0         1         0     0
# 82473                0     0         1         0     0
# 82659                1     0         0         0     0
# 84339                0     0         1         0     0
# 85249                0     0         0         1     0
# 86640                0     0         1         0     0
# 86941                0     0         1         0     0
# 87730                1     0         0         0     0
# 91880                0     0         0         1     0
# 93893                0     0         0         1     0
# 94139                0     0         1         0     0
# 94518                0     0         1         0     0
# 97083                0     0         1         0     0
# 98207                0     0         1         0     0
# 101088               1     0         0         0     0
#
# [144 rows x 47 columns]

# %%
df.drop(['race'], axis=1, inplace=True)

# %%
df.head(10)
# Out:
#       patient_nbr  gender      age  admission_type_id  \
# 1755     82255599  Female  [50-60)                  6
# 1983     66062943    Male  [50-60)                  6
# 2079     77283603  Female  [70-80)                  6
# 2308    103731444  Female  [70-80)                  6
# 3276     64565010    Male  [70-80)                  6
# 4856     69532245  Female  [60-70)                  6
# 5015     50977674  Female  [50-60)                  6
# 5312     60115239  Female  [70-80)                  6
# 5387    109789992    Male  [80-90)                  6
# 5770     58968585  Female  [70-80)                  6
#
#       discharge_disposition_id  admission_source_id  time_in_hospital  \
# 1755                         1                    7                 2
# 1983                        10                    1                 4
# 2079                         1                    7                 3
# 2308                         6                    7                 6
# 3276                         3                    7                 4
# 4856                         1                    7                 6
# 5015                         1                    7                 5
# 5312                         1                    7                 7
# 5387                         1                    7                 4
# 5770                         1                    7                 4
#
#      medical_specialty  num_lab_procedures  num_procedures  ...  citoglipton  \
# 1755  InternalMedicine                  43               0  ...           No
# 1983   Surgery-General                  41               1  ...           No
# 2079  InternalMedicine                  43               0  ...           No
# 2308  InternalMedicine                  69               0  ...           No
# 3276  InternalMedicine                  64               0  ...           No
# 4856  InternalMedicine                  77               3  ...           No
# 5015  InternalMedicine                  95               2  ...           No
# 5312  InternalMedicine                  67               0  ...           No
# 5387  InternalMedicine                  74               3  ...           No
# 5770  InternalMedicine                  65               0  ...           No
#
#       insulin  glyburide-metformin  glipizide-metformin  \
# 1755       No                   No                   No
# 1983       No                   No                   No
# 2079       No                   No                   No
# 2308       No                   No                   No
# 3276       No                   No                   No
# 4856   Steady                   No                   No
# 5015   Steady                   No                   No
# 5312       No                   No                   No
# 5387       No                   No                   No
# 5770   Steady                   No                   No
#
#      glimepiride-pioglitazone metformin-rosiglitazone metformin-pioglitazone  \
# 1755                       No                      No                     No
# 1983                       No                      No                     No
# 2079                       No                      No                     No
# 2308                       No                      No                     No
# 3276                       No                      No                     No
# 4856                       No                      No                     No
# 5015                       No                      No                     No
# 5312                       No                      No                     No
# 5387                       No                      No                     No
# 5770                       No                      No                     No
#
#       change diabetesMed readmitted
# 1755      No          No        >30
# 1983      No         Yes        >30
# 2079      No          No        >30
# 2308      No          No        >30
# 3276      No         Yes        >30
# 4856      No         Yes        >30
# 5015      No         Yes        >30
# 5312      No          No         NO
# 5387      No          No        >30
# 5770      No         Yes        >30
#
# [10 rows x 41 columns]

# %%
df = pd.get_dummies(df, columns=['gender', 'age', 'change', 'diabetesMed'], drop_first=True)

# %%
df.head(10)
# Out:
#       patient_nbr  admission_type_id  discharge_disposition_id  \
# 1755     82255599                  6                         1
# 1983     66062943                  6                        10
# 2079     77283603                  6                         1
# 2308    103731444                  6                         6
# 3276     64565010                  6                         3
# 4856     69532245                  6                         1
# 5015     50977674                  6                         1
# 5312     60115239                  6                         1
# 5387    109789992                  6                         1
# 5770     58968585                  6                         1
#
#       admission_source_id  time_in_hospital medical_specialty  \
# 1755                    7                 2  InternalMedicine
# 1983                    1                 4   Surgery-General
# 2079                    7                 3  InternalMedicine
# 2308                    7                 6  InternalMedicine
# 3276                    7                 4  InternalMedicine
# 4856                    7                 6  InternalMedicine
# 5015                    7                 5  InternalMedicine
# 5312                    7                 7  InternalMedicine
# 5387                    7                 4  InternalMedicine
# 5770                    7                 4  InternalMedicine
#
#       num_lab_procedures  num_procedures  num_medications  number_outpatient  \
# 1755                  43               0               13                  0
# 1983                  41               1                8                  0
# 2079                  43               0                3                  0
# 2308                  69               0               17                  0
# 3276                  64               0                3                  0
# 4856                  77               3               28                  0
# 5015                  95               2               11                  0
# 5312                  67               0               10                  0
# 5387                  74               3               11                  0
# 5770                  65               0               14                  0
#
#       ...  gender_Male  age_[20-30) age_[30-40) age_[40-50) age_[50-60)  \
# 1755  ...            0            0           0           0           1
# 1983  ...            1            0           0           0           1
# 2079  ...            0            0           0           0           0
# 2308  ...            0            0           0           0           0
# 3276  ...            1            0           0           0           0
# 4856  ...            0            0           0           0           0
# 5015  ...            0            0           0           0           1
# 5312  ...            0            0           0           0           0
# 5387  ...            1            0           0           0           0
# 5770  ...            0            0           0           0           0
#
#       age_[60-70) age_[70-80) age_[80-90) change_No diabetesMed_Yes
# 1755            0           0           0         1               0
# 1983            0           0           0         1               1
# 2079            0           1           0         1               0
# 2308            0           1           0         1               0
# 3276            0           1           0         1               1
# 4856            1           0           0         1               1
# 5015            0           0           0         1               1
# 5312            0           1           0         1               0
# 5387            0           0           1         1               0
# 5770            0           1           0         1               1
#
# [10 rows x 47 columns]

# %%
df = pd.get_dummies(df, columns=['insulin'], drop_first=True)

# %%
from sklearn import preprocessing
le = preprocessing.LabelEncoder()
df = df.apply(le.fit_transform)

# %%
from sklearn.model_selection import train_test_split
from sklearn.tree import DecisionTreeClassifier

# %%
y = df.readmitted
X_train, X_test, y_train, y_test = train_test_split(df, y, test_size=0.3, random_state=42)

# %%
model = DecisionTreeClassifier()
model.fit(X=X_train, y=y_train)
# Out:
# DecisionTreeClassifier(class_weight=None, criterion='gini', max_depth=None,
#             max_features=None, max_leaf_nodes=None,
#             min_impurity_decrease=0.0, min_impurity_split=None,
#             min_samples_leaf=1, min_samples_split=2,
#             min_weight_fraction_leaf=0.0, presort=False, random_state=None,
#             splitter='best')

# %%
model.score(X=X_test, y=y_test)
# Out:
# 1.0
